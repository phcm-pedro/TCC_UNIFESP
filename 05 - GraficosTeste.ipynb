# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Criar um conjunto de dados desequilibrado
X, y = make_classification(
    n_classes=2,
    class_sep=2,
    weights=[0.1, 0.9],
    n_informative=3,
    n_redundant=1,
    flip_y=0,
    n_features=20,
    n_clusters_per_class=1,
    n_samples=1000,
    random_state=42
)

# Dividir o conjunto de dados em treino e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Função para visualizar os dados e os resultados do balanceamento
def plot_resampling(X_resampled, y_resampled, title):
    plt.figure(figsize=(10, 6))

    # Plotar os dados originais
    plt.subplot(1, 2, 1)
    class_counts_original = pd.Series(y_train).value_counts()
    class_counts_original.plot(kind='bar', color=['skyblue', 'orange'])
    plt.title('Dados Originais')

    # Plotar os dados após o resampling
    plt.subplot(1, 2, 2)
    class_counts_resampled = pd.Series(y_resampled).value_counts()
    class_counts_resampled.plot(kind='bar', color=['skyblue', 'orange'])
    plt.title(title)

    plt.show()

# Oversampling
ros = RandomOverSampler(random_state=42)
X_ros, y_ros = ros.fit_resample(X_train, y_train)
plot_resampling(X_ros, y_ros, 'Random Oversampling')

# Undersampling
rus = RandomUnderSampler(random_state=42)
X_rus, y_rus = rus.fit_resample(X_train, y_train)
plot_resampling(X_rus, y_rus, 'Random Undersampling')

# Combinação de Oversampling e Undersampling
ros = RandomOverSampler(sampling_strategy=0.5, random_state=42)
rus = RandomUnderSampler(sampling_strategy=0.5, random_state=42)

X_comb, y_comb = ros.fit_resample(X_train, y_train)
X_comb, y_comb = rus.fit_resample(X_comb, y_comb)

plot_resampling(X_comb, y_comb, 'Combined Resampling')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(25,7))
plt.subplot(1,4,1)
dict  = {'X': ['Classe 0', 'Classe 1'], 'Y': [600,70]}
df = pd.DataFrame(dict)
plt.title('Distribuição dados originais', fontsize=14, fontweight='bold')
plt.bar(df['X'], df['Y'],color=['skyblue', 'orange'])
plt.ylim(0, 650)
plt.tick_params(axis='both', labelsize=13)
plt.subplot(1,4,2)
dict  = {'X': ['Classe 0', 'Classe 1'], 'Y': [70,70]}
df = pd.DataFrame(dict)
plt.title('Distribuição dados em subamostragem', fontsize=14, fontweight='bold')
plt.bar(df['X'], df['Y'],color=['skyblue', 'orange'])
plt.ylim(0, 650)
plt.tick_params(axis='both', labelsize=12)
plt.subplot(1,4,3)
dict  = {'X': ['Classe 0', 'Classe 1'], 'Y': [600,600]}
df = pd.DataFrame(dict)
plt.title('Distribuição dados em sobreamostragem', fontsize=14, fontweight='bold')
plt.bar(df['X'], df['Y'],color=['skyblue', 'orange'])
plt.ylim(0, 650)
plt.tick_params(axis='both', labelsize=12)
plt.subplot(1,4,4)
dict  = {'X': ['Classe 0', 'Classe 1'], 'Y': [350,350]}
df = pd.DataFrame(dict)
plt.title('Distribuição dados em sub + sobreamostragem', fontsize=14, fontweight='bold')
plt.bar(df['X'], df['Y'],color=['skyblue', 'orange'])
plt.ylim(0, 650)
plt.tick_params(axis='both', labelsize=12)

# %%
df
# Out:
#    X    Y
# 0  0  600
# 1  1   30
